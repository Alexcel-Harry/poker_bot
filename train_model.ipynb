# %%
# !pip install rlcard[torch] eval7

# %%
# !python train_improved_v2.py

# %%
# In Colab, run this in a new cell:
from google.colab import files
import shutil

# Create zip
shutil.make_archive('poker_model_2M', 'zip', 'poker_model_improved_v2')

# Download
files.download('poker_model_2M.zip')
